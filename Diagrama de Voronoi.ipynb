# %%
# Importar librerias
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial import Voronoi, voronoi_plot_2d

#Algunos puntos
Points=np.random.rand(15, 2)
np.random.seed(12)

Points = np.append(Points, [[999,999], [-999,999], [-999,-999], [999,-999]], axis = 0)
#Computamos la teselación de Voronoi
vor= Voronoi(Points)

#Graficar
voronoi_plot_2d(vor)
plt.show()

#Color
for region in vor.regions:
  if not -1 in region:
    polygon= [vor.vertices[i] for i in region]
    plt.fill(*zip(*polygon))

# Restringer el gráfico

# %%
Points
# Out:
# array([[0.28522108, 0.30424514],
#        [0.65813731, 0.21021411],
#        [0.35849891, 0.18637037],
#        [0.74809938, 0.48271238],
#        [0.75765154, 0.72169521],
#        [0.67779842, 0.9806353 ],
#        [0.95599758, 0.20952441],
#        [0.14250358, 0.70254592],
#        [0.68589378, 0.76606247],
#        [0.84943395, 0.64534638],
#        [0.80924057, 0.60062761],
#        [0.95443561, 0.99009823],
#        [0.85172519, 0.60813139],
#        [0.9503976 , 0.08627214],
#        [0.42947408, 0.03459075]])
